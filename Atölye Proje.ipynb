# %%
#pip install pandas

# %%
#pip install numpy

# %%
import pandas as pd 
import numpy as np

# %%
# !pip install xlrd

# %%
yıllara_gore_seragazi_miktari = pd.read_excel("C:\\Users\\melek\\Downloads\\sera gazi emisyonlari (milyon ton co2 esdegeri).xls")

# %%
sektorlere_gore_seragazi_miktari = pd.read_excel("C:\\Users\\melek\\Downloads\\sektorlere gore toplam sera gazi emisyonlari (milyon ton co2 esdegeri).xls")

# %%
pd.DataFrame(yıllara_gore_seragazi_miktari)
# Out:
#     Yıl\nYear  Toplam\nTotal         CO2        CH4        N2O  \
# 0        1990     228.433396  154.572094  51.257113  22.179528
# 1        1991     235.953849  161.125931  52.341015  21.986631
# 2        1992     242.341247  167.234001  52.191366  22.449048
# 3        1993     249.663009  174.291143  51.754136  23.151535
# 4        1994     243.286625  170.592417  51.328388  20.949170
# 5        1995     257.036676  184.674708  50.777794  21.216527
# 6        1996     276.414894  203.097942  51.123062  21.812370
# 7        1997     287.317801  215.511523  50.048762  21.375394
# 8        1998     288.717426  215.585837  50.229894  22.520047
# 9        1999     286.192931  211.238081  51.786532  22.786785
# 10       2000     306.970992  232.933969  51.531901  22.018596
# 11       2001     288.133786  216.872489  50.583518  20.084182
# 12       2002     293.060492  224.319769  47.896567  20.076601
# 13       2003     312.753677  239.848552  50.607624  21.332267
# ...

# %%
pd.DataFrame(sektorlere_gore_seragazi_miktari)
# Out:
#     Yıl\nYear  Toplam\nTotal  \
# 0        1990     228.433396
# 1        1991     235.953849
# 2        1992     242.341247
# 3        1993     249.663009
# 4        1994     243.286625
# 5        1995     257.036676
# 6        1996     276.414894
# 7        1997     287.317801
# 8        1998     288.717426
# 9        1999     286.192931
# 10       2000     306.970992
# 11       2001     288.133786
# 12       2002     293.060492
# 13       2003     312.753677
# 14       2004     322.350103
# 15       2005     345.502175
# 16       2006     366.029471
# 17       2007     399.910870
# 18       2008     395.877281
# 19       2009     402.373269
# 20       2010     406.424426
# 21       2011     436.023251
# 22       2012     456.366874
# 23       2013     448.747508
# 24       2014     468.000473
# 25       2015     481.457787
# 26       2016     504.993973
# 27       2017     532.379759
# 28       2018     529.736077
# 29       2019     517.850211
# 30       2020     532.133784
# ...

# %%
yıllara_gore_seragazi_miktari.columns = ['Yıl', 'Toplam', 'CO2', 'CH4', 'N2O', 'F_gazlar']

# %%
yıllara_gore_seragazi_miktari
# Out:
#      Yıl      Toplam         CO2        CH4        N2O   F_gazlar
# 0   1990  228.433396  154.572094  51.257113  22.179528   0.424662
# 1   1991  235.953849  161.125931  52.341015  21.986631   0.500272
# 2   1992  242.341247  167.234001  52.191366  22.449048   0.466832
# 3   1993  249.663009  174.291143  51.754136  23.151535   0.466195
# 4   1994  243.286625  170.592417  51.328388  20.949170   0.416650
# 5   1995  257.036676  184.674708  50.777794  21.216527   0.367648
# 6   1996  276.414894  203.097942  51.123062  21.812370   0.381520
# 7   1997  287.317801  215.511523  50.048762  21.375394   0.382123
# 8   1998  288.717426  215.585837  50.229894  22.520047   0.381648
# 9   1999  286.192931  211.238081  51.786532  22.786785   0.381533
# 10  2000  306.970992  232.933969  51.531901  22.018596   0.486525
# 11  2001  288.133786  216.872489  50.583518  20.084182   0.593596
# 12  2002  293.060492  224.319769  47.896567  20.076601   0.767555
# ...

# %%
sektorlere_gore_seragazi_miktari.columns=['Yıl','Toplam','1990 yılına göre değişim (%)','Enerji','Endüstriyel işlemler ve ürün kullanımı','Tarım','Atık']

# %%
sektorlere_gore_seragazi_miktari
# Out:
#      Yıl      Toplam 1990 yılına göre değişim (%)      Enerji  \
# 0   1990  228.433396                            -  143.177601
# 1   1991  235.953849                     3.292186  147.547696
# 2   1992  242.341247                     6.088361  154.018727
# 3   1993  249.663009                     9.293568  160.426675
# 4   1994  243.286625                     6.502214  156.751432
# 5   1995  257.036676                    12.521496  169.978405
# 6   1996  276.414894                     21.00459  187.779318
# 7   1997  287.317801                    25.777494  199.930808
# 8   1998  288.717426                      26.3902  199.712788
# 9   1999  286.192931                    25.285066  197.781662
# 10  2000  306.970992                     34.38096  219.764033
# 11  2001  288.133786                    26.134703  203.102090
# 12  2002  293.060492                    28.291439  209.555730
# 13  2003  312.753677                    36.912414  223.921019
# ...

# %%
yıllara_gore_seragazi_miktari.head(5)
# Out:
#    Yıl\nYear  Toplam\nTotal         CO2        CH4        N2O  \
# 0       1990     228.433396  154.572094  51.257113  22.179528
# 1       1991     235.953849  161.125931  52.341015  21.986631
# 2       1992     242.341247  167.234001  52.191366  22.449048
# 3       1993     249.663009  174.291143  51.754136  23.151535
# 4       1994     243.286625  170.592417  51.328388  20.949170
#
#    F-gazlar\nF-gases
# 0           0.424662
# 1           0.500272
# 2           0.466832
# 3           0.466195
# 4           0.416650

# %%
yıllara_gore_seragazi_miktari.tail(5)
# Out:
#     Yıl\nYear  Toplam\nTotal         CO2        CH4        N2O  \
# 29       2019     517.850211  406.567763  72.960048  32.899175
# 30       2020     532.133784  416.328049  73.498377  36.114923
# 31       2021     574.120550  457.377292  73.919631  35.924089
# 32       2022     560.200971  443.602703  71.910757  34.287371
# 33       2023     598.917090  486.944575  66.586243  35.473630
#
#     F-gazlar\nF-gases
# 29           5.423225
# 30           6.192434
# 31           6.899538
# 32          10.400140
# 33           9.912642

# %%
sektorlere_gore_seragazi_miktari.head(5)
# Out:
#    Yıl\nYear  Toplam\nTotal  \
# 0       1990     228.433396
# 1       1991     235.953849
# 2       1992     242.341247
# 3       1993     249.663009
# 4       1994     243.286625
#
#   1990 yılına göre değişim (%)\nChange compared to \n1990 (%)  \
# 0                                                  -
# 1                                           3.292186
# 2                                           6.088361
# 3                                           9.293568
# 4                                           6.502214
#
#    Enerji\nEnergy   \
# 0       143.177601
# 1       147.547696
# 2       154.018727
# 3       160.426675
# 4       156.751432
#
#    Endüstriyel işlemler ve ürün kullanımı\nIndustrial processes and product use  \
# 0                                          23.092077
# 1                                          24.890180
# 2                                          24.643606
# 3                                          25.142729
# ...

# %%
sektorlere_gore_seragazi_miktari.tail(5)
# Out:
#     Yıl\nYear  Toplam\nTotal  \
# 29       2019     517.850211
# 30       2020     532.133784
# 31       2021     574.120550
# 32       2022     560.200971
# 33       2023     598.917090
#
#    1990 yılına göre değişim (%)\nChange compared to \n1990 (%)  \
# 29                                         126.696367
# 30                                         132.949207
# 31                                         151.329516
# 32                                          145.23602
# 33                                         162.184558
#
#     Enerji\nEnergy   \
# 29       369.290460
# 30       369.776298
# 31       406.769699
# 32       400.739692
# 33       442.170298
#
#     Endüstriyel işlemler ve ürün kullanımı\nIndustrial processes and product use  \
# 29                                          60.270058
# 30                                          68.936929
# 31                                          76.542722
# 32                                          71.934925
# ...

# %%
yıllara_gore_seragazi_miktari.axes
# Out:
# [RangeIndex(start=0, stop=34, step=1),
#  Index(['Yıl\nYear', 'Toplam\nTotal', 'CO2', 'CH4', 'N2O', 'F-gazlar\nF-gases'], dtype='object')]

# %%
sektorlere_gore_seragazi_miktari.axes
# Out:
# [RangeIndex(start=0, stop=34, step=1),
#  Index(['Yıl', 'Toplam', '1990 yılına göre değişim (%)', 'Enerji',
#         'Endüstriyel işlemler ve ürün kullanımı', 'Tarım', 'Atık'],
#        dtype='object')]

# %%
print(yıllara_gore_seragazi_miktari.isnull().sum())
# Out:
# Yıl         0
# Toplam      0
# CO2         0
# CH4         0
# N2O         0
# F_gazlar    0
# dtype: int64

# %%
print(sektorlere_gore_seragazi_miktari.isnull().sum())
# Out:
# Yıl                                       0
# Toplam                                    0
# 1990 yılına göre değişim (%)              0
# Enerji                                    0
# Endüstriyel işlemler ve ürün kullanımı    0
# Tarım                                     0
# Atık                                      0
# dtype: int64

# %%
print(yıllara_gore_seragazi_miktari.dtypes)
# Out:
# Yıl           int64
# Toplam      float64
# CO2         float64
# CH4         float64
# N2O         float64
# F_gazlar    float64
# dtype: object

# %%
print(sektorlere_gore_seragazi_miktari.dtypes)
# Out:
# Yıl                                         int64
# Toplam                                    float64
# 1990 yılına göre değişim (%)               object
# Enerji                                    float64
# Endüstriyel işlemler ve ürün kullanımı    float64
# Tarım                                     float64
# Atık                                      float64
# dtype: object
